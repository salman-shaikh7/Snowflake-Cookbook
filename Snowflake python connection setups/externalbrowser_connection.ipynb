# %%
import pandas as pd
import snowflake.connector

# %%
connection = snowflake.connector.connect(
        account = "",
        user = "",
        authenticator="externalbrowser",
        role = "",
        warehouse = "",
        database = "",
        schema = ""
)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://login.microsoftonline.com/944a2343-09e7-4e7b-ac43-1eda5afef90d/saml2?SAMLRequest=nZJbc9owEIX%2Fikd9tmUbO2ANkCFh0jIlLeVSOnkT9ho0kSVXK8dJf32FHWbSh%2BShb7qcs%2Fq0Z8fXz5X0nsCg0GpCoiAkHqhcF0IdJ2S3vfNHxEPLVcGlVjAhL4DkejpGXsmazRp7Umv43QBazxVSyLqLCWmMYpqjQKZ4Bchszjaz%2ByWLg5DVRluda0neWD52cEQw1hFeLAUKh3eytmaUtm0btINAmyONwzCkYUad6iz5dNE%2Fuz%2B9o49omJz1TuHkq1e2G6H6FnyEdehFyL5styt%2F9X2zJd7sgnqrFTYVmA2YJ5HDbr3sAdARHKU%2BcOme7Oy9AP2jxACVbkvJHyHXVd1Ydx24FS2hoFIfhWvAYj4h9aMo1sPRn2zJR5W4qfMmfoh4esp%2BiP2uSn%2FBQYj73Qg%2Bf033h%2F0iJ97PS8LxOeEFYgMLdc7VuqMwTv0w86OrbTRkYcyiLEivkgfizV2uQnHbOS%2FwHUdQidxo1KXVSgoFHWWWJDweJANXDIZ%2BAsODz3O3jaDgKS%2BhzMKCntOOST9BrAMx0%2F%2Fty5i%2BrfI6lN9cTov5SkuRv3h32lTcvh9jFETdiSj8spMyqLiQs6IwgOjilFK3twa4dbNvTQOETvtX%2F53%2B6V8%3D&RelayState=ver%3A1-hint%3A295949135626670-ETMsDgAAAZlTeiusABRBRVMvQ0JDL1BLQ1M1UGFkZGluZwEAABAAEI0Xw5eEICMGSm8TQJwTBdQAAACgNe0JqC8VWqGPC0JA6g1kC8PGr8TG9DT7yRioagGJz%2F%2F1E6ayYrSGbag6Nb4X3Oyc2d03JqOEa6AGNXSQfsF9uxGVR%2BLQSF0C8aeytNFrFJ8RBi71h7lxgOMp%2F8o3Kr8EXhjiJqViQVDA5HqGuZRmPBeFq%2Fvlgk%2F%2FHJwJZr5cJo9wYqX4gj2d6WtV1iWMMZdDJSYo7570TeEQT6poJj9DMgAUzdxx98vFkkwspmvD6RaZXTvmHlg%3D to authenticate...

# %%
cur=connection.cursor()

# %%
cur.execute('SELECT CURRENT_USER(), CURRENT_ROLE()')

# %%
result = cur.fetchone()

# %%
result

# %%
cur.close()
# Out:
# True
